# %% [markdown]
# # How to Train YOLOv9 on a Custom Dataset
# ---
#
# [![Roboflow](https://raw.githubusercontent.com/roboflow-ai/notebooks/main/assets/badges/roboflow-blogpost.svg)](https://blog.roboflow.com/train-yolov9-model/)
# [![GitHub](https://badges.aleen42.com/src/github.svg)](https://github.com/WongKinYiu/yolov9)
# [![YouTube](https://badges.aleen42.com/src/youtube.svg)](https://youtu.be/XHT2c8jT3Bc)
# [![arXiv](https://img.shields.io/badge/arXiv-2402.13616-b31b1b.svg)](https://arxiv.org/pdf/2402.13616.pdf)

# %% [markdown]
# ## Before you start
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Wed Apr 10 05:49:12 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# **NOTE:** To make it easier for us to manage datasets, images and models we create a `HOME` constant.

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ## Clone and Install

# %% [markdown]
# **NOTE:** YOLOv9 is very new. At the moment, we recommend using a fork of the main repository. The `detect.py` script contains a bug that prevents inference. This bug is patched in the fork.

# %%
# !git clone https://github.com/SkalskiP/yolov9.git
# %cd yolov9
# !pip install -r requirements.txt -q
# Out:
# Cloning into 'yolov9'...
# remote: Enumerating objects: 325, done.
# remote: Total 325 (delta 0), reused 0 (delta 0), pack-reused 325
# Receiving objects: 100% (325/325), 2.25 MiB | 5.25 MiB/s, done.
# Resolving deltas: 100% (164/164), done.
# /content/yolov9
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 5.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 20.0 MB/s eta 0:00:00

# %% [markdown]
# **NOTE:** Let's install the [`roboflow`](https://pypi.org/project/roboflow) package, which we will use to download our dataset from [Roboflow Universe](https://universe.roboflow.com/).

# %%
# !pip install -q roboflow
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 2.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 10.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 19.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 7.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 11.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.7 MB/s eta 0:00:00

# %% [markdown]
# ## Download model weights

# %% [markdown]
# **NOTE:** In the YOLOv9 paper, versions `yolov9-s` and `yolov9-m` are also mentioned, but the weights for these models are not yet available in the YOLOv9 [repository](https://github.com/WongKinYiu/yolov9).

# %%
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-c.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-e.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-c.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-e.pt

# %%
# !ls -la {HOME}/weights
# Out:
# total 402440
# drwxr-xr-x 2 root root      4096 Apr 10 05:53 .
# drwxr-xr-x 1 root root      4096 Apr 10 05:53 ..
# -rw-r--r-- 1 root root  51508261 Feb 18 12:36 gelan-c.pt
# -rw-r--r-- 1 root root 117203713 Feb 18 12:36 gelan-e.pt
# -rw-r--r-- 1 root root 103153312 Feb 18 12:36 yolov9-c.pt
# -rw-r--r-- 1 root root 140217688 Feb 18 12:36 yolov9-e.pt

# %% [markdown]
# ## Download example data

# %% [markdown]
# **NOTE:** If you want to run inference using your own file as input, simply upload image to Google Colab and update `SOURCE_IMAGE_PATH` with the path leading to your file.

# %% [markdown]
# ## Detection with pre-trained COCO model

# %% [markdown]
# ### gelan-c

# %%
# !python detect.py --weights {HOME}/weights/gelan-c.pt --conf 0.1 --source {HOME}/data/dog.jpeg --device 0
# Out:
# detect: weights=['/content/weights/gelan-c.pt'], source=/content/data/dog.jpeg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 467 layers, 25472640 parameters, 0 gradients, 102.8 GFLOPs
# image 1/1 /content/data/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 1 handbag, 235.8ms
# Speed: 0.6ms pre-process, 235.8ms inference, 704.3ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp

# %% [markdown]
# **NOTE:** By default, the results of each subsequent inference sessions are saved in `{HOME}/yolov9/runs/detect/`, in directories named `exp`, `exp2`, `exp3`, ... You can override this behavior by using the `--name` parameter.

# %% [markdown]
# ## yolov9-e

# %%
# !python detect.py --weights {HOME}/weights/yolov9-e.pt --conf 0.1 --source {HOME}/data/dog.jpeg --device 0
# Out:
# detect: weights=['/content/weights/yolov9-e.pt'], source=/content/data/dog.jpeg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 1119 layers, 69470144 parameters, 0 gradients, 244.0 GFLOPs
# image 1/1 /content/data/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 1 backpack, 1 handbag, 169.4ms
# Speed: 0.5ms pre-process, 169.4ms inference, 489.2ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp2

# %% [markdown]
# ## Authenticate and Download the Dataset

# %% [markdown]
# **NOTE:** The dataset must be saved inside the `{HOME}/yolov9` directory, otherwise, the training will not succeed.

# %%
# %cd {HOME}/yolov9

# %% [markdown]
# **NOTE:** In this tutorial, I will use the [football-players-detection](https://universe.roboflow.com/roboflow-jvuqo/football-players-detection-3zvbc) dataset. Feel free to replace it with your dataset in YOLO format or use another dataset available on [Roboflow Universe](https://universe.roboflow.com). Additionally, if you plan to deploy your model to Roboflow after training, make sure you are the owner of the dataset and that no model is associated with the version of the dataset you are going to training on.

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="ZOPETSNpOENTPTAZXRyk")
project = rf.workspace("ueh-tb3hq").project("facial-landmark-125ft")
version = project.version(9)
dataset = version.download("yolov9")
# Out:
# Requirement already satisfied: roboflow in /usr/local/lib/python3.10/dist-packages (1.1.26)
# Requirement already satisfied: certifi==2023.7.22 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2023.7.22)
# Requirement already satisfied: chardet==4.0.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.0.0)
# Requirement already satisfied: cycler==0.10.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (0.10.0)
# Requirement already satisfied: idna==2.10 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.10)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.4.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from roboflow) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.25.2)
# Requirement already satisfied: opencv-python-headless==4.8.0.74 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.8.0.74)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from roboflow) (9.4.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.8.2)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.0.7)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.66.2)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (6.0.1)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.0.0)
# Requirement already satisfied: python-magic in /usr/local/lib/python3.10/dist-packages (from roboflow) (0.4.27)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (1.2.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (4.50.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->roboflow) (3.3.2)
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Facial-Landmark-9 to yolov9:: 100%|██████████| 33932/33932 [00:00<00:00, 50601.02it/s]
# Extracting Dataset Version Zip to Facial-Landmark-9 in yolov9:: 100%|██████████| 2012/2012 [00:00<00:00, 7949.65it/s]

# %% [markdown]
# ## Train Custom Model

# %%
# %cd {HOME}/yolov9

# !python train.py \
--batch 16 --epochs 25 --img 640 --device 0 --min-items 0 --close-mosaic 15 \
--data {dataset.location}/data.yaml \
--weights {HOME}/weights/gelan-c.pt \
--cfg models/detect/gelan-c.yaml \
--hyp hyp.scratch-high.yaml
# Out:
# /content/yolov9
# 2024-04-10 05:58:35.012947: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-10 05:58:35.013006: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-10 05:58:35.014381: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-10 05:58:36.085360: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# train: weights=/content/weights/gelan-c.pt, cfg=models/detect/gelan-c.yaml, data=/content/yolov9/Facial-Landmark-9/data.yaml, hyp=hyp.scratch-high.yaml, epochs=25, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, flat_cos_lr=False, fixed_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, min_items=0, close_mosaic=15, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, cls_pw=1.0, dfl=1.5, obj_pw=1.0, iou_t=0.2, anchor_t=5.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.9, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.15, copy_paste=0.3
# ClearML: run 'pip install clearml' to automatically track, visualize and remotely train YOLO 🚀 in ClearML
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLO 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 25.0MB/s]
# Overriding model.yaml nc=80 with nc=54
#
#                  from  n    params  module                                  arguments
#   0                -1  1      1856  models.common.Conv                      [3, 64, 3, 2]
#   1                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   2                -1  1    212864  models.common.RepNCSPELAN4              [128, 256, 128, 64, 1]
#   3                -1  1    164352  models.common.ADown                     [256, 256]
#   4                -1  1    847616  models.common.RepNCSPELAN4              [256, 512, 256, 128, 1]
#   5                -1  1    656384  models.common.ADown                     [512, 512]
#   6                -1  1   2857472  models.common.RepNCSPELAN4              [512, 512, 512, 256, 1]
#   7                -1  1    656384  models.common.ADown                     [512, 512]
#   8                -1  1   2857472  models.common.RepNCSPELAN4              [512, 512, 512, 256, 1]
#   9                -1  1    656896  models.common.SPPELAN                   [512, 512, 256]
#  10                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  11           [-1, 6]  1         0  models.common.Concat                    [1]
#  12                -1  1   3119616  models.common.RepNCSPELAN4              [1024, 512, 512, 256, 1]
#  13                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  14           [-1, 4]  1         0  models.common.Concat                    [1]
#  15                -1  1    912640  models.common.RepNCSPELAN4              [1024, 256, 256, 128, 1]
#  16                -1  1    164352  models.common.ADown                     [256, 256]
#  17          [-1, 12]  1         0  models.common.Concat                    [1]
#  18                -1  1   2988544  models.common.RepNCSPELAN4              [768, 512, 512, 256, 1]
#  19                -1  1    656384  models.common.ADown                     [512, 512]
#  20           [-1, 9]  1         0  models.common.Concat                    [1]
#  21                -1  1   3119616  models.common.RepNCSPELAN4              [1024, 512, 512, 256, 1]
#  22      [15, 18, 21]  1   5532274  models.yolo.DDetect                     [54, [256, 512, 512]]
# gelan-c summary: 621 layers, 25478706 parameters, 25478690 gradients, 103.4 GFLOPs
#
# Transferred 931/937 items from /content/weights/gelan-c.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 154 weight(decay=0.0), 161 weight(decay=0.0005), 160 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# train: Scanning /content/yolov9/Facial-Landmark-9/train/labels... 701 images, 0 backgrounds, 0 corrupt: 100% 701/701 [00:00<00:00, 1446.54it/s]
# train: New cache created: /content/yolov9/Facial-Landmark-9/train/labels.cache
# val: Scanning /content/yolov9/Facial-Landmark-9/valid/labels... 199 images, 0 backgrounds, 0 corrupt: 100% 199/199 [00:00<00:00, 1441.63it/s]
# val: New cache created: /content/yolov9/Facial-Landmark-9/valid/labels.cache
# Plotting labels to runs/train/exp/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/train/exp
# Starting training for 25 epochs...
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        0/24      12.2G      5.055      48.95      1.616        213        640: 100% 44/44 [00:51<00:00,  1.17s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 7/7 [00:06<00:00,  1.13it/s]
#                    all        199       4634      0.356    0.00265   0.000796   0.000156
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/24      13.5G      4.433      5.516      1.058        184        640: 100% 44/44 [00:37<00:00,  1.17it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 7/7 [00:04<00:00,  1.51it/s]
#                    all        199       4634      0.222     0.0273    0.00747    0.00147
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/24      13.5G      4.287      4.332      1.042        403        640: 100% 44/44 [00:37<00:00,  1.18it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 7/7 [00:04<00:00,  1.51it/s]
#                    all        199       4634      0.291     0.0254    0.00733    0.00143
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/24      13.5G      4.131      3.841      1.004        311        640: 100% 44/44 [00:37<00:00,  1.17it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 7/7 [00:04<00:00,  1.47it/s]
#                    all        199       4634      0.144     0.0298    0.00648    0.00138
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/24      13.5G      4.183      3.241      1.005        359        640: 100% 44/44 [00:38<00:00,  1.15it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 7/7 [00:04<00:00,  1.47it/s]
#                    all        199       4634      0.227     0.0366     0.0133    0.00311
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/24      13.5G      3.994      2.901     0.9995        354        640: 100% 44/44 [00:37<00:00,  1.16it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 7/7 [00:04<00:00,  1.46it/s]
#                    all        199       4634      0.318     0.0604     0.0241    0.00557
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/24      13.5G      3.936      2.686      0.981        470        640: 100% 44/44 [00:37<00:00,  1.17it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 7/7 [00:05<00:00,  1.39it/s]
#                    all        199       4634      0.281     0.0602     0.0277    0.00628
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/24      13.5G      3.817      2.603     0.9751        277        640: 100% 44/44 [00:37<00:00,  1.16it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 7/7 [00:04<00:00,  1.47it/s]
#                    all        199       4634      0.301     0.0422     0.0248     0.0055
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/24      13.5G      3.761      2.469     0.9627        290        640: 100% 44/44 [00:38<00:00,  1.15it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 7/7 [00:04<00:00,  1.40it/s]
#                    all        199       4634      0.328     0.0566     0.0337    0.00808
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/24      13.5G      3.715      2.375     0.9561        330        640: 100% 44/44 [00:38<00:00,  1.15it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 7/7 [00:04<00:00,  1.45it/s]
#                    all        199       4634      0.231     0.0846     0.0372    0.00882
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/24      13.5G      3.481      2.205      1.015        183        640: 100% 44/44 [00:36<00:00,  1.21it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 7/7 [00:05<00:00,  1.37it/s]
#                    all        199       4634      0.171     0.0955     0.0473     0.0111
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/24      13.5G      3.417       2.12      1.008        247        640: 100% 44/44 [00:35<00:00,  1.25it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 7/7 [00:04<00:00,  1.45it/s]
#                    all        199       4634      0.225     0.0951     0.0465     0.0117
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/24      13.5G       3.37      2.024     0.9838        154        640: 100% 44/44 [00:35<00:00,  1.22it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 7/7 [00:05<00:00,  1.36it/s]
#                    all        199       4634      0.216     0.0927     0.0494     0.0121
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/24      13.5G      3.336      2.029     0.9779        287        640: 100% 44/44 [00:35<00:00,  1.25it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 7/7 [00:04<00:00,  1.44it/s]
#                    all        199       4634      0.156        0.1     0.0493     0.0124
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/24      13.5G       3.36      2.005     0.9789        210        640: 100% 44/44 [00:35<00:00,  1.25it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 7/7 [00:04<00:00,  1.44it/s]
#                    all        199       4634      0.293      0.106      0.061     0.0159
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/24      13.5G      3.261       1.97     0.9702        285        640: 100% 44/44 [00:35<00:00,  1.24it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 7/7 [00:04<00:00,  1.41it/s]
#                    all        199       4634      0.178      0.104     0.0569     0.0145
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/24      13.5G      3.213      1.947     0.9813        178        640: 100% 44/44 [00:35<00:00,  1.24it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 7/7 [00:04<00:00,  1.45it/s]
#                    all        199       4634      0.132      0.121     0.0574     0.0148
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/24      13.5G      3.148      1.873     0.9637        158        640: 100% 44/44 [00:35<00:00,  1.25it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 7/7 [00:05<00:00,  1.39it/s]
#                    all        199       4634      0.177      0.121     0.0642     0.0159
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/24      13.5G      3.112      1.881     0.9695        246        640: 100% 44/44 [00:35<00:00,  1.25it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 7/7 [00:04<00:00,  1.44it/s]
#                    all        199       4634      0.183      0.143     0.0707     0.0186
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/24      13.5G      3.146      1.911     0.9498        201        640: 100% 44/44 [00:35<00:00,  1.24it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 7/7 [00:05<00:00,  1.37it/s]
#                    all        199       4634      0.174      0.137      0.072     0.0189
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/24      13.5G      3.102      1.868     0.9582        252        640: 100% 44/44 [00:35<00:00,  1.25it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 7/7 [00:04<00:00,  1.41it/s]
#                    all        199       4634       0.18      0.155     0.0845     0.0223
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/24      13.5G       3.07      1.809     0.9428        188        640: 100% 44/44 [00:35<00:00,  1.25it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 7/7 [00:04<00:00,  1.44it/s]
#                    all        199       4634      0.181      0.157     0.0864     0.0228
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/24      13.5G      3.051      1.826     0.9488        179        640: 100% 44/44 [00:35<00:00,  1.24it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 7/7 [00:05<00:00,  1.37it/s]
#                    all        199       4634      0.187      0.158     0.0846     0.0243
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/24      13.5G      3.055      1.777     0.9352        282        640: 100% 44/44 [00:35<00:00,  1.25it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 7/7 [00:04<00:00,  1.43it/s]
#                    all        199       4634      0.189      0.162     0.0873     0.0231
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/24      13.5G      2.969      1.766     0.9345        205        640: 100% 44/44 [00:35<00:00,  1.25it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 7/7 [00:04<00:00,  1.44it/s]
#                    all        199       4634      0.167      0.177     0.0968     0.0271
#
# 25 epochs completed in 0.309 hours.
# Optimizer stripped from runs/train/exp/weights/last.pt, saved as runs/train/exp/weights/last_striped.pt, 51.5MB
# Optimizer stripped from runs/train/exp/weights/best.pt, saved as runs/train/exp/weights/best_striped.pt, 51.5MB
#
# Validating runs/train/exp/weights/best.pt...
# Fusing layers...
# gelan-c summary: 467 layers, 25452594 parameters, 0 gradients, 102.7 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 7/7 [00:15<00:00,  2.25s/it]
#                    all        199       4634      0.166      0.176     0.0966      0.027
#                      0        199         15      0.473        0.2      0.237     0.0659
#                      1        199         17          0          0     0.0419     0.0141
#                     10        199         33      0.157      0.182     0.0644     0.0143
#                     11        199         32      0.179       0.25     0.0836     0.0234
#                     12        199         29       0.18       0.31      0.139     0.0381
#                     13        199         23      0.142      0.174      0.158     0.0593
#                     14        199         23      0.121      0.087     0.0343    0.00953
#                     15        199          1          0          0          0          0
#                     16        199         29      0.141      0.172     0.0804     0.0297
#                     17        199         69     0.0528      0.058     0.0166    0.00307
#                     18        199         49      0.119      0.143     0.0872     0.0269
#                     19        199         24      0.107      0.208     0.0516     0.0216
#                      2        199         15          0          0     0.0312    0.00702
#                     20        199         29      0.062      0.138     0.0629     0.0194
#                     21        199         23      0.322      0.217      0.239     0.0888
#                     22        199         29      0.151      0.294     0.0874     0.0188
#                     23        199         23      0.156     0.0435     0.0798     0.0246
#                     24        199         13      0.133     0.0769     0.0493     0.0252
#                     25        199         33      0.143      0.121      0.109     0.0321
#                     26        199         29      0.134      0.103     0.0786     0.0185
#                      3        199         29      0.105      0.172     0.0963     0.0247
#                      4        199         23          1          0    0.00243   0.000348
#                      5        199         23      0.287      0.217      0.122     0.0423
#                      6        199         12      0.143      0.333      0.196     0.0313
#                      7        199         23     0.0714      0.087     0.0453    0.00884
#                      8        199         12          0          0    0.00863    0.00201
#                      9        199         49     0.0986      0.102      0.045     0.0127
#                     ac        199        244      0.262      0.336      0.191     0.0429
#                     al        199        249      0.144      0.197     0.0884     0.0238
#                      c        199        166      0.199      0.211      0.127     0.0367
#                     ch        199        170       0.29      0.418      0.227     0.0631
#                     cm        199        170      0.255      0.459      0.219     0.0618
#                     en        199         86       0.34      0.419      0.306     0.0935
#                     ex        199        171      0.112      0.158     0.0547      0.013
#                     ft        199        169      0.145      0.154     0.0627     0.0171
#                      g        199        128      0.112      0.188     0.0498     0.0114
#                     gn        199        129        0.1       0.14     0.0437     0.0121
#                     li        199        131      0.239      0.321      0.177     0.0425
#                     ll        199        169      0.345      0.515      0.266     0.0672
#                     ls        199        129      0.225       0.31      0.138     0.0345
#                     mf        199         84    0.00951     0.0119     0.0102     0.0023
#                     mp        199        171      0.316      0.386      0.241     0.0715
#                      n        199        129     0.0857      0.116     0.0429    0.00798
#                     pg        199        129     0.0977      0.101     0.0378    0.00836
#                    pra        199         80     0.0563       0.05     0.0127    0.00277
#                    prn        199        166      0.169      0.205     0.0741     0.0151
#                      r        199         49     0.0583      0.102     0.0158    0.00458
#                     sa        199         75     0.0908     0.0626     0.0241    0.00743
#                    sba        199         85     0.0712     0.0824     0.0256    0.00596
#                     sn        199        167      0.263      0.287      0.168     0.0448
#                     st        199        153      0.276      0.438      0.276     0.0849
#                     tr        199        126          0          0     0.0119    0.00221
#              undefined        199        315      0.151      0.146     0.0594      0.016
#                     zy        199         85     0.0641     0.0118     0.0179    0.00324
# Results saved to runs/train/exp

# %% [markdown]
# ## Examine Training Results

# %% [markdown]
# **NOTE:** By default, the results of each subsequent training sessions are saved in `{HOME}/yolov9/runs/train/`, in directories named `exp`, `exp2`, `exp3`, ... You can override this behavior by using the `--name` parameter.

# %%
# !ls {HOME}/yolov9/runs/train/exp/
# Out:
# confusion_matrix.png				    PR_curve.png	   val_batch0_pred.jpg
# events.out.tfevents.1712728716.b192bdd2fefd.3412.0  R_curve.png		   val_batch1_labels.jpg
# F1_curve.png					    results.csv		   val_batch1_pred.jpg
# hyp.yaml					    results.png		   val_batch2_labels.jpg
# labels_correlogram.jpg				    train_batch0.jpg	   val_batch2_pred.jpg
# labels.jpg					    train_batch1.jpg	   weights
# opt.yaml					    train_batch2.jpg
# P_curve.png					    val_batch0_labels.jpg

# %%
from IPython.display import Image

Image(filename=f"{HOME}/yolov9/runs/train/exp/results.png", width=1000)

# %%
from IPython.display import Image

Image(filename=f"{HOME}/yolov9/runs/train/exp/confusion_matrix.png", width=1000)

# %%
from IPython.display import Image

Image(filename=f"{HOME}/yolov9/runs/train/exp/val_batch0_pred.jpg", width=1000)

# %% [markdown]
# ## Validate Custom Model

# %%
# %cd {HOME}/yolov9

# !python val.py \
--img 640 --batch 32 --conf 0.001 --iou 0.7 --device 0 \
--data {dataset.location}/data.yaml \
--weights {HOME}/yolov9/runs/train/exp/weights/best.pt
# Out:
# /content/yolov9
# val: data=/content/yolov9/Facial-Landmark-9/data.yaml, weights=['/content/yolov9/runs/train/exp/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.7, max_det=300, task=val, device=0, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False, min_items=0
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# gelan-c summary: 467 layers, 25452594 parameters, 0 gradients, 102.7 GFLOPs
# val: Scanning /content/yolov9/Facial-Landmark-9/valid/labels.cache... 199 images, 0 backgrounds, 0 corrupt: 100% 199/199 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 7/7 [00:17<00:00,  2.56s/it]
#                    all        199       4634      0.168      0.179     0.0984     0.0271
# Speed: 0.4ms pre-process, 35.8ms inference, 19.1ms NMS per image at shape (32, 3, 640, 640)
# Results saved to runs/val/exp

# %% [markdown]
# ## Inference with Custom Model

# %%
# !python detect.py \
--img 1280 --conf 0.1 --device 0 \
--weights {HOME}/yolov9/runs/train/exp/weights/best.pt \
--source {dataset.location}/test/images
# Out:
# detect: weights=['/content/yolov9/runs/train/exp/weights/best.pt'], source=/content/yolov9/Facial-Landmark-9/test/images, data=data/coco128.yaml, imgsz=[1280, 1280], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# gelan-c summary: 467 layers, 25452594 parameters, 0 gradients, 102.7 GFLOPs
# image 1/100 /content/yolov9/Facial-Landmark-9/test/images/DSC07652_JPG.rf.f76fbaa02e334603f46763d465622acf.jpg: 1280x1280 1 ac, 2 als, 2 cs, 2 chs, 2 cms, 2 exs, 4 gs, 2 lis, 1 ll, 1 ls, 1 mp, 1 pg, 1 sba, 2 sns, 1 st, 2 undefineds, 141.2ms
# image 2/100 /content/yolov9/Facial-Landmark-9/test/images/DSC07713_JPG.rf.b8ec7c1e1e7cd447b21df9e41fa650ef.jpg: 1280x1280 1 al, 1 c, 1 ch, 1 ex, 2 gs, 2 gns, 1 li, 1 ll, 1 ls, 1 mp, 2 pgs, 1 prn, 1 sba, 2 sns, 105.1ms
# image 3/100 /content/yolov9/Facial-Landmark-9/test/images/DSC07756_JPG.rf.66a93ffbc41daa498b93f2f6d0f79ff2.jpg: 1280x1280 1 ac, 1 ch, 2 cms, 2 exs, 2 gs, 2 lis, 1 ll, 1 ls, 1 mp, 3 pgs, 1 prn, 1 sba, 1 sn, 2 sts, 1 undefined, 106.6ms
# image 4/100 /content/yolov9/Facial-Landmark-9/test/images/DSC07762_JPG.rf.ad7acc18b9646739bcb25900bc070493.jpg: 1280x1280 1 ac, 1 al, 1 c, 3 chs, 2 cms, 2 exs, 1 g, 1 li, 2 lls, 2 lss, 1 mp, 1 pra, 1 prn, 1 sba, 1 sn, 1 st, 2 undefineds, 105.1ms
# image 5/100 /content/yolov9/Facial-Landmark-9/test/images/DSC08455_JPG.rf.0afcbffdcff884b5a1c6716b6f2f652c.jpg: 1280x1280 2 acs, 1 al, 1 c, 4 undefineds, 103.6ms
# image 6/100 /content/yolov9/Facial-Landmark-9/test/images/DSC08476_JPG.rf.f35bac4481903f94b0e38409d58a4dd7.jpg: 1280x1280 1 ac, 3 als, 2 cs, 1 ch, 2 cms, 2 exs, 1 g, 1 li, 1 ll, 1 ls, 1 mp, 1 pg, 3 pras, 1 prn, 2 sas, 1 sba, 2 sns, 2 sts, 106.3ms
# image 7/100 /content/yolov9/Facial-Landmark-9/test/images/DSC08770_JPG.rf.6199dba5dd3bc55dffc5c1207f2f614f.jpg: 1280x1280 2 acs, 1 c, 1 prn, 5 undefineds, 105.6ms
# image 8/100 /content/yolov9/Facial-Landmark-9/test/images/DSC09012_JPG.rf.800a2e49b79668464bc27ddc5735ba72.jpg: 1280x1280 4 acs, 2 als, 2 cs, 2 chs, 3 cms, 1 en, 3 exs, 3 fts, 1 g, 1 li, 4 lls, 1 ls, 2 mps, 2 ns, 1 sn, 2 sts, 2 undefineds, 104.0ms
# image 9/100 /content/yolov9/Facial-Landmark-9/test/images/DSC09039_JPG.rf.dda56534648f17208d52ee9875170d83.jpg: 1280x1280 1 ac, 2 als, 1 ch, 2 cms, 1 ex, 2 gs, 2 lis, 1 ll, 1 ls, 1 mp, 1 n, 1 pra, 2 rs, 2 sas, 1 sn, 1 st, 104.8ms
# image 10/100 /content/yolov9/Facial-Landmark-9/test/images/DSC09193_JPG.rf.2fb270a4b215c8f424450d4172df740d.jpg: 1280x1280 1 ac, 1 prn, 2 undefineds, 105.4ms
# image 11/100 /content/yolov9/Facial-Landmark-9/test/images/DSC09204_JPG.rf.e02404bcd8a96f45d45df4428a207fbe.jpg: 1280x1280 3 acs, 3 als, 2 cs, 2 chs, 4 cms, 4 ens, 4 exs, 4 fts, 1 li, 4 lls, 1 ls, 2 mps, 2 prns, 1 sn, 2 sts, 4 undefineds, 105.4ms
# image 12/100 /content/yolov9/Facial-Landmark-9/test/images/DSC09211_JPG.rf.487410fbd9fc14a6e5509b1a49648abc.jpg: 1280x1280 2 cs, 2 chs, 2 cms, 2 exs, 1 ft, 1 g, 2 gns, 2 lis, 1 ll, 1 ls, 1 mp, 1 n, 1 pg, 2 pras, 1 prn, 1 sa, 1 sba, 1 sn, 1 st, 1 undefined, 103.6ms
# image 13/100 /content/yolov9/Facial-Landmark-9/test/images/DSC09217_JPG.rf.3a563dcd9b135d3b790f986fb8c7f7d4.jpg: 1280x1280 2 acs, 3 als, 3 cs, 2 chs, 4 cms, 2 ens, 5 exs, 1 ft, 2 gs, 2 gns, 2 lis, 4 lls, 1 ls, 1 mf, 2 mps, 1 n, 2 prns, 1 sa, 2 sns, 3 sts, 105.2ms
# image 14/100 /content/yolov9/Facial-Landmark-9/test/images/DSC09223_JPG.rf.abf7fe71c3c9fd5bb6003f8f132d621d.jpg: 1280x1280 1 ac, 1 c, 3 undefineds, 104.9ms
# image 15/100 /content/yolov9/Facial-Landmark-9/test/images/DSC09362_JPG.rf.656d0658953846d9b527e38d53a7e4ce.jpg: 1280x1280 2 acs, 3 als, 1 c, 2 chs, 2 cms, 2 ens, 6 exs, 3 fts, 2 gs, 1 gn, 1 li, 3 lls, 1 ls, 1 mf, 2 mps, 2 ns, 1 pg, 3 prns, 1 sn, 2 sts, 2 undefineds, 104.8ms
# image 16/100 /content/yolov9/Facial-Landmark-9/test/images/DSC09373_JPG.rf.01cabd9387eaac3057cc65fdc85dcf84.jpg: 1280x1280 1 ac, 2 als, 1 c, 2 chs, 1 cm, 3 exs, 1 g, 2 lis, 1 ll, 3 lss, 1 mp, 2 ns, 2 pgs, 1 prn, 2 sns, 1 st, 1 undefined, 106.3ms
# image 17/100 /content/yolov9/Facial-Landmark-9/test/images/DSC09379_JPG.rf.e079ddcfafa42f908afde2fc0aa22f08.jpg: 1280x1280 1 ac, 2 als, 2 cs, 1 ch, 2 cms, 2 exs, 2 gs, 1 gn, 2 lis, 1 ll, 1 ls, 1 mp, 2 ns, 2 pgs, 1 pra, 1 prn, 2 sas, 1 sba, 1 sn, 1 st, 1 undefined, 104.3ms
# image 18/100 /content/yolov9/Facial-Landmark-9/test/images/DSC09391_JPG.rf.4a86a6d662789f5c0df1f92533313ca5.jpg: 1280x1280 3 acs, 3 als, 2 cs, 2 chs, 3 cms, 2 ens, 8 exs, 2 fts, 2 gs, 1 gn, 1 li, 5 lls, 1 ls, 1 mf, 2 mps, 2 prns, 1 sn, 2 sts, 4 undefineds, 105.8ms
# image 19/100 /content/yolov9/Facial-Landmark-9/test/images/DSC09404_JPG.rf.dc1a0d970698a3be9531bd39b121cacd.jpg: 1280x1280 1 ac, 1 al, 1 c, 1 ch, 2 cms, 2 exs, 2 gs, 3 gns, 2 lis, 2 lls, 1 ls, 1 mp, 2 ns, 2 pgs, 2 prns, 1 sn, 1 st, 1 undefined, 105.5ms
# image 20/100 /content/yolov9/Facial-Landmark-9/test/images/DSC09413_JPG.rf.4c98972aedeb7f6ccbfc2827eea34d34.jpg: 1280x1280 2 acs, 3 als, 1 c, 2 chs, 1 cm, 2 exs, 1 g, 3 gns, 2 lis, 1 ll, 1 ls, 1 mp, 1 n, 1 pg, 1 pra, 2 prns, 1 sa, 2 sns, 1 st, 104.7ms
# image 21/100 /content/yolov9/Facial-Landmark-9/test/images/DSC09558_JPG.rf.f79aa874762b638bc346a28de6e60bbf.jpg: 1280x1280 4 acs, 1 al, 1 c, 2 chs, 2 cms, 2 ens, 4 exs, 4 fts, 1 g, 1 gn, 2 lis, 4 lls, 1 ls, 2 mps, 1 pg, 3 prns, 1 sn, 2 sts, 4 undefineds, 105.1ms
# image 22/100 /content/yolov9/Facial-Landmark-9/test/images/DSC09571_JPG.rf.4d35205cc89d5960b9817b5d87b1fb02.jpg: 1280x1280 2 acs, 1 al, 2 cs, 1 ch, 1 cm, 3 exs, 1 g, 2 gns, 1 li, 2 lls, 1 mp, 2 ns, 2 pgs, 1 pra, 1 prn, 1 sa, 1 sn, 1 st, 103.8ms
# image 23/100 /content/yolov9/Facial-Landmark-9/test/images/DSC09578_JPG.rf.2967a3418ad8bf6d65e3a3a922d315fe.jpg: 1280x1280 1 ac, 2 cs, 1 ch, 1 cm, 1 ex, 2 gs, 2 gns, 1 li, 2 lls, 1 ls, 1 mp, 1 n, 2 pgs, 2 prns, 1 sa, 2 sns, 1 st, 104.9ms
# image 24/100 /content/yolov9/Facial-Landmark-9/test/images/DSC09675_JPG.rf.32356b9cb82b0afc0a4696da9861e8c7.jpg: 1280x1280 2 acs, 1 c, 1 ch, 1 cm, 1 ex, 2 gs, 2 gns, 2 lis, 1 ll, 1 ls, 1 mp, 2 ns, 1 pg, 1 prn, 1 r, 1 sn, 2 undefineds, 105.6ms
# image 25/100 /content/yolov9/Facial-Landmark-9/test/images/DSC09708_JPG.rf.59353dfd9acb47274cc81251d8149d56.jpg: 1280x1280 2 acs, 2 als, 1 c, 3 chs, 1 cm, 2 ens, 3 exs, 4 fts, 2 gs, 1 gn, 1 li, 2 lls, 1 ls, 3 mfs, 2 mps, 1 n, 1 pg, 2 prns, 2 sns, 2 sts, 2 undefineds, 105.3ms
# image 26/100 /content/yolov9/Facial-Landmark-9/test/images/DSC09856_JPG.rf.26ddf167edd288111c4d86bd250d8dfe.jpg: 1280x1280 1 20, 2 acs, 3 als, 2 cs, 2 chs, 2 cms, 2 ens, 2 exs, 2 fts, 2 gs, 2 gns, 1 li, 3 lls, 1 ls, 2 mps, 3 pgs, 3 prns, 1 sn, 2 sts, 3 undefineds, 105.4ms
# image 27/100 /content/yolov9/Facial-Landmark-9/test/images/DSC09860_JPG.rf.2f6c3e6d1226497966635b04cf60d0d7.jpg: 1280x1280 2 acs, 1 al, 1 c, 1 ch, 1 cm, 1 ex, 4 gs, 1 gn, 1 li, 1 ll, 2 lss, 1 mp, 2 ns, 1 pg, 1 prn, 1 sba, 2 sns, 104.5ms
# image 28/100 /content/yolov9/Facial-Landmark-9/test/images/DSC09868_JPG.rf.17721d360b69dc861d949644cb64834a.jpg: 1280x1280 1 ac, 1 al, 1 c, 1 ch, 2 cms, 1 ex, 1 g, 3 gns, 1 li, 1 ll, 1 ls, 1 mp, 1 n, 1 pg, 2 prns, 1 r, 1 sba, 1 sn, 1 st, 105.7ms
# image 29/100 /content/yolov9/Facial-Landmark-9/test/images/DSC09942_JPG.rf.19fc4344f714fdff52b75825770ae56e.jpg: 1280x1280 4 acs, 3 als, 2 cs, 2 chs, 2 cms, 3 ens, 4 exs, 5 fts, 1 g, 1 gn, 2 lis, 3 lls, 1 ls, 2 mps, 2 ns, 1 pg, 3 prns, 1 sn, 3 sts, 2 undefineds, 106.1ms
# image 30/100 /content/yolov9/Facial-Landmark-9/test/images/DSC09945_JPG.rf.185024c182d11791118cd0fa6f83ca82.jpg: 1280x1280 1 10, 2 acs, 2 als, 1 c, 1 sn, 3 undefineds, 104.4ms
# image 31/100 /content/yolov9/Facial-Landmark-9/test/images/DSC09971_JPG.rf.42f9c1da398b8bb34457faa8a59d71c0.jpg: 1280x1280 1 22, 1 ac, 1 al, 2 cs, 2 chs, 1 cm, 2 exs, 3 gs, 2 gns, 2 lis, 2 lls, 1 ls, 1 n, 1 pg, 1 prn, 1 sn, 1 st, 1 undefined, 105.8ms
# image 32/100 /content/yolov9/Facial-Landmark-9/test/images/DSC09976_JPG.rf.718d7344c9bfa004ab831ffb0d030ee6.jpg: 1280x1280 1 ac, 1 c, 1 ch, 1 cm, 2 exs, 1 g, 3 gns, 2 lls, 1 ls, 1 mp, 2 ns, 2 pgs, 1 prn, 1 sn, 2 sts, 1 undefined, 106.4ms
# image 33/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF0004_JPG.rf.152545db1393ca8564124a7aa6e77fdd.jpg: 1280x1280 1 3, 1 ac, 2 als, 1 c, 1 ch, 1 cm, 1 ft, 2 gs, 2 gns, 1 li, 1 ll, 1 ls, 2 mps, 2 ns, 1 pg, 1 prn, 1 sba, 1 sn, 2 sts, 1 undefined, 105.1ms
# image 34/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF0007_JPG.rf.20757e1f15483c957f74b7416aa7bac6.jpg: 1280x1280 1 3, 1 ac, 2 als, 1 c, 1 ch, 1 cm, 1 ex, 1 ft, 1 g, 2 gns, 1 li, 1 ll, 1 ls, 1 mp, 1 n, 1 pg, 1 prn, 1 sba, 1 sn, 1 st, 2 undefineds, 104.4ms
# image 35/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF0220_JPG.rf.fff406c2fe6314ce3106d13f256dfee1.jpg: 1280x1280 (no detections), 105.2ms
# image 36/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF0475_JPG.rf.fe864f969e2d1c746ef09be5d82239ff.jpg: 1280x1280 1 ac, 1 c, 1 ch, 1 cm, 1 ex, 1 g, 1 li, 1 ll, 1 mp, 1 pg, 1 prn, 2 sbas, 1 sn, 105.8ms
# image 37/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF0562_JPG.rf.d7ed9a8fa8a3b4b35b0e190e49831342.jpg: 1280x1280 2 20s, 1 22, 1 6, 3 acs, 3 als, 1 c, 2 chs, 1 cm, 2 ens, 1 ex, 2 fts, 1 g, 1 li, 2 lls, 1 ls, 2 mps, 1 n, 1 sn, 3 undefineds, 105.4ms
# image 38/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF1634_JPG.rf.243abcd4f44f55cc5469f47596641961.jpg: 1280x1280 1 11, 2 16s, 2 19s, 2 20s, 2 22s, 1 ac, 1 al, 1 c, 1 ch, 1 cm, 2 ens, 2 exs, 2 fts, 2 gs, 1 gn, 1 li, 2 lls, 1 ls, 105.2ms
# image 39/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF1645_JPG.rf.1d84472fd1c9cdf1d4403a26f85d146e.jpg: 1280x1280 1 10, 1 18, 1 ac, 1 al, 1 sn, 1 undefined, 106.5ms
# image 40/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF1646_JPG.rf.940e177e5111399634297976c66c4035.jpg: 1280x1280 1 ac, 1 c, 1 ch, 1 cm, 1 ex, 1 g, 1 gn, 1 li, 1 ll, 1 ls, 1 mp, 1 pg, 1 pra, 1 prn, 1 sa, 1 sn, 1 st, 1 undefined, 105.7ms
# image 41/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF1651_JPG.rf.3c08a83261218dd044018fd8fd584178.jpg: 1280x1280 1 ac, 2 als, 1 c, 1 ch, 2 cms, 1 ex, 1 ft, 1 g, 1 gn, 1 li, 1 ll, 1 ls, 2 ns, 1 pg, 1 pra, 1 prn, 1 sa, 1 sba, 1 sn, 1 st, 2 undefineds, 104.3ms
# image 42/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF1706_JPG.rf.9d18cb36a4ed03d58b981d6a7e391474.jpg: 1280x1280 2 16s, 3 20s, 1 22, 2 acs, 3 als, 1 c, 2 chs, 2 cms, 2 ens, 1 ex, 2 fts, 1 g, 1 li, 2 lls, 1 ls, 1 mf, 1 prn, 1 sn, 3 undefineds, 105.6ms
# image 43/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF1964_JPG.rf.26c53d1364206a35afc009f577f21051.jpg: 1280x1280 1 16, 2 20s, 1 22, 1 6, 2 acs, 2 als, 1 c, 2 chs, 2 cms, 2 ens, 3 exs, 1 ft, 1 g, 1 gn, 2 lis, 2 lls, 1 ls, 1 mf, 1 mp, 1 n, 1 sn, 2 sts, 1 undefined, 105.2ms
# image 44/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF1969_JPG.rf.adef26492fbd65853298f3c48d9eb3bf.jpg: 1280x1280 2 als, 2 undefineds, 105.5ms
# image 45/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF1990_JPG.rf.1b67dd018a8f308caabae2532553b2b5.jpg: 1280x1280 1 20, 1 3, 1 al, 2 cs, 1 ch, 1 cm, 1 g, 1 gn, 1 li, 1 ls, 1 mp, 1 n, 1 pg, 1 sn, 1 st, 105.6ms
# image 46/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF1996_JPG.rf.ed58f1cb954a062165732c55a14525b7.jpg: 1280x1280 1 14, 1 16, 1 20, 1 ac, 2 als, 1 c, 1 ch, 2 cms, 1 ex, 1 g, 1 li, 1 ll, 1 ls, 2 ns, 1 pg, 1 prn, 1 sn, 1 undefined, 105.5ms
# image 47/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF2005_JPG.rf.7596a9f7a329586e50c9788e7bbdc5ff.jpg: 1280x1280 1 16, 2 20s, 2 22s, 2 6s, 2 als, 1 c, 2 chs, 1 cm, 1 en, 1 ex, 1 ft, 2 gs, 1 li, 2 lls, 1 ls, 1 mp, 1 sn, 1 undefined, 104.6ms
# image 48/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF2022_JPG.rf.fddd323a9d768dcf51afc8a63663ad89.jpg: 1280x1280 2 acs, 1 al, 1 c, 1 sn, 2 undefineds, 104.7ms
# image 49/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF2106_JPG.rf.945703f94a721d11fb5f3143ffb0ff0f.jpg: 1280x1280 1 16, 2 19s, 2 20s, 2 22s, 1 6, 2 acs, 3 als, 1 c, 2 chs, 2 cms, 2 ens, 2 fts, 2 gs, 1 gn, 1 li, 2 lls, 1 ls, 1 mf, 2 mps, 1 prn, 1 sn, 1 st, 1 undefined, 107.2ms
# image 50/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF2111_JPG.rf.dbe233b3933884d34b81e0f1d3f516d9.jpg: 1280x1280 1 11, 1 17, 1 25, 1 ac, 2 als, 2 undefineds, 105.8ms
# image 51/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF2130_JPG.rf.d4e315f7a286ddbb17e4eabec2ea6521.jpg: 1280x1280 1 20, 1 ac, 1 al, 1 ch, 1 cm, 2 fts, 1 g, 2 gns, 1 li, 1 ll, 1 mp, 1 pg, 1 prn, 1 sba, 1 sn, 1 st, 106.0ms
# image 52/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF2131_JPG.rf.923507ef767fa2f8a33741af83b5e67c.jpg: 1280x1280 1 20, 1 ac, 1 al, 1 c, 1 ch, 1 cm, 1 ex, 1 ft, 1 g, 2 gns, 1 li, 1 ls, 1 n, 2 pgs, 1 prn, 1 sba, 1 sn, 1 st, 104.2ms
# image 53/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF2136_JPG.rf.333c4dbc2055c24b4a1616ab95810b5a.jpg: 1280x1280 1 ac, 1 al, 2 cs, 1 ch, 1 cm, 1 ft, 1 g, 1 li, 1 ll, 1 ls, 1 mp, 2 pgs, 2 pras, 1 prn, 1 sa, 1 sba, 1 sn, 1 st, 1 undefined, 105.5ms
# image 54/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF2209_JPG.rf.43ef2e0e9fa0cc083ec1c7bd5b698bc1.jpg: 1280x1280 2 19s, 1 20, 3 acs, 2 als, 2 cs, 2 chs, 2 cms, 2 ens, 1 ex, 4 fts, 1 g, 1 gn, 3 lls, 3 mps, 1 sn, 2 sts, 2 undefineds, 104.2ms
# image 55/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF2212_JPG.rf.3b3578f0cfb1ae3b748cfe3d32253674.jpg: 1280x1280 3 acs, 3 als, 1 c, 1 sn, 3 undefineds, 105.1ms
# image 56/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF2244_JPG.rf.6398058d053f2772fe3c83074ae02a07.jpg: 1280x1280 1 16, 1 ac, 1 al, 1 c, 1 ch, 1 cm, 1 ex, 1 ft, 1 g, 1 gn, 2 lls, 1 ls, 1 n, 1 pg, 1 prn, 1 sba, 1 sn, 2 sts, 106.8ms
# image 57/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF2250_JPG.rf.945aadec333f5c42373635464d43ac96.jpg: 1280x1280 1 13, 1 ac, 2 als, 1 c, 1 ch, 1 cm, 2 exs, 1 ft, 2 gs, 1 gn, 1 ll, 1 ls, 1 mp, 2 ns, 2 pgs, 1 prn, 1 sba, 1 sn, 2 undefineds, 105.6ms
# image 58/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF2557_JPG.rf.a555a72a7b48e20476b93207ab9994b9.jpg: 1280x1280 1 20, 3 acs, 2 als, 1 c, 2 chs, 3 cms, 2 ens, 2 exs, 2 fts, 2 gs, 1 li, 3 lls, 1 ls, 2 mps, 1 sn, 2 sts, 2 undefineds, 105.1ms
# image 59/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF2565_JPG.rf.85998751ae211edcfa24bbbffdca1b25.jpg: 1280x1280 1 ac, 1 c, 1 prn, 1 sn, 2 undefineds, 105.7ms
# image 60/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF2592_JPG.rf.c351e8cff1efc7c6af9c3253e70fe1eb.jpg: 1280x1280 1 ac, 2 als, 2 cs, 1 ch, 1 cm, 1 ex, 1 g, 2 gns, 1 li, 1 ll, 1 ls, 1 mp, 1 pg, 2 pras, 1 prn, 1 sa, 1 sba, 1 sn, 1 st, 105.3ms
# image 61/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF2604_JPG.rf.ea5d0769835e07f283ee2fa7ed5084a8.jpg: 1280x1280 1 ac, 2 als, 1 c, 1 ch, 2 cms, 1 ex, 1 ft, 1 g, 1 li, 1 ll, 1 mp, 2 ns, 1 pg, 2 pras, 1 prn, 1 sa, 1 sn, 1 st, 2 undefineds, 105.8ms
# image 62/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF2651_JPG.rf.9789aac8046d5b166204ea6840829597.jpg: 1280x1280 1 20, 4 acs, 3 als, 1 c, 2 chs, 2 cms, 2 ens, 2 exs, 3 fts, 1 g, 1 li, 2 lls, 1 ls, 2 mps, 1 sn, 2 sts, 3 undefineds, 105.6ms
# image 63/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF2655_JPG.rf.44106b73365ebd3417347ac19f10ac6f.jpg: 1280x1280 3 acs, 1 sn, 3 undefineds, 105.3ms
# image 64/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF2687_JPG.rf.89aa7ddb579e6d9dc762459ee2f86381.jpg: 1280x1280 1 20, 1 22, 1 al, 1 c, 1 g, 1 li, 1 ll, 1 prn, 104.6ms
# image 65/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF2699_JPG.rf.92451c6c4214c98478389687f67b0736.jpg: 1280x1280 1 5, 1 ac, 1 al, 1 c, 1 ch, 1 cm, 1 ex, 1 li, 1 ll, 1 ls, 2 ns, 2 pgs, 1 sba, 1 undefined, 105.0ms
# image 66/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF2720_JPG.rf.7f4e89cc9ff2cd0fb8f030bd31e4d604.jpg: 1280x1280 3 acs, 4 undefineds, 104.5ms
# image 67/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF2733_JPG.rf.8292ecf803321b8527bec8cfa66d9cf4.jpg: 1280x1280 2 acs, 1 al, 2 cs, 1 ch, 1 cm, 2 exs, 2 fts, 1 g, 1 li, 1 ll, 1 ls, 2 mps, 2 ns, 1 pg, 1 prn, 1 sba, 1 sn, 1 st, 1 undefined, 105.6ms
# image 68/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF2918_JPG.rf.8eaaad31a8a6c3579251451d6ccb41f8.jpg: 1280x1280 1 22, 4 acs, 2 als, 1 c, 2 chs, 2 cms, 1 en, 3 exs, 3 fts, 2 gs, 1 li, 4 lls, 1 ls, 1 mf, 2 mps, 1 prn, 1 sn, 2 sts, 4 undefineds, 106.3ms
# image 69/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF2927_JPG.rf.98e126bee334a270593a6d14cc042548.jpg: 1280x1280 1 13, 2 16s, 2 19s, 2 20s, 1 22, 1 3, 1 6, 2 acs, 2 als, 1 c, 1 ch, 2 cms, 1 en, 1 ex, 2 fts, 1 g, 2 lls, 1 mp, 1 prn, 1 sn, 1 st, 1 undefined, 106.1ms
# image 70/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF2933_JPG.rf.ff13390d59eaf9af3a770b94adbed37b.jpg: 1280x1280 1 18, 1 9, 1 ac, 1 c, 1 sn, 3 undefineds, 106.9ms
# image 71/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF2951_JPG.rf.bbee356d3e0cea51db4ebf63e6b286e7.jpg: 1280x1280 1 20, 1 3, 1 9, 1 ch, 2 cms, 1 ft, 2 gs, 1 gn, 1 li, 1 ls, 1 mp, 3 ns, 1 pg, 1 sba, 1 st, 1 undefined, 105.8ms
# image 72/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF2955_JPG.rf.32b849559141fbac5afec34ecb7ebbca.jpg: 1280x1280 1 13, 1 18, 1 20, 1 9, 2 cs, 1 ch, 1 cm, 1 ex, 1 ft, 1 g, 1 li, 1 ll, 1 mp, 1 n, 1 pg, 2 pras, 1 prn, 1 sa, 1 sba, 1 st, 105.7ms
# image 73/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF3271_JPG.rf.db8208004707febb87f5067fa9d5fe30.jpg: 1280x1280 1 ac, 2 als, 1 c, 2 chs, 1 cm, 1 ex, 1 g, 1 li, 1 ll, 1 ls, 1 mp, 1 prn, 2 sbas, 1 sn, 1 st, 2 undefineds, 106.1ms
# image 74/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF3281_JPG.rf.01b3d4823c0cae24b6589fed6cd7aa23.jpg: 1280x1280 2 acs, 2 als, 1 c, 1 ch, 1 cm, 2 fts, 1 g, 2 lis, 1 ll, 1 ls, 1 mp, 1 n, 1 prn, 2 sns, 1 st, 2 undefineds, 105.8ms
# image 75/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF3686_JPG.rf.1e44fcd319c328271c9927f9374e5488.jpg: 1280x1280 2 acs, 2 als, 1 c, 2 chs, 2 cms, 2 ens, 2 exs, 4 fts, 1 g, 1 gn, 1 li, 2 lls, 1 ls, 2 mps, 1 pg, 1 sn, 2 sts, 2 undefineds, 106.3ms
# image 76/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF3688_JPG.rf.2822db1f6c53bc1acab600858ebf01c8.jpg: 1280x1280 1 ac, 1 al, 1 c, 1 sn, 3 undefineds, 105.6ms
# image 77/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF3987_JPG.rf.c3290f649b50225cec0aa14c055140c3.jpg: 1280x1280 1 ac, 4 als, 1 c, 1 prn, 1 sn, 6 undefineds, 105.5ms
# image 78/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF4017_JPG.rf.2c1a5aeaaf36884ec9f623b05ba56d47.jpg: 1280x1280 1 22, 2 acs, 2 als, 1 c, 1 ch, 1 cm, 1 ex, 1 ft, 3 gs, 1 li, 1 ll, 1 ls, 1 mp, 2 pgs, 1 prn, 1 sa, 1 sba, 1 sn, 2 sts, 106.6ms
# image 79/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF4027_JPG.rf.526b183b9a1b4aea0be7e688015de943.jpg: 1280x1280 1 19, 1 20, 1 22, 1 ac, 1 al, 2 chs, 1 gn, 2 lis, 1 ll, 1 ls, 2 ns, 1 pg, 1 prn, 1 sa, 4 undefineds, 104.3ms
# image 80/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF4088_JPG.rf.90f9a6a6ab92dd745b06d7c52436097b.jpg: 1280x1280 2 16s, 1 20, 2 22s, 3 acs, 2 als, 1 c, 2 chs, 1 cm, 2 ens, 1 ex, 3 fts, 1 g, 1 li, 3 lls, 1 ls, 1 mf, 1 sn, 2 sts, 3 undefineds, 106.3ms
# image 81/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF6018_JPG.rf.981d964f473b5d38c7f276541e3618c3.jpg: 1280x1280 2 acs, 2 als, 1 c, 2 chs, 2 cms, 1 ex, 1 ft, 1 g, 2 lis, 1 ll, 1 mp, 1 pg, 1 prn, 1 sba, 1 sn, 1 st, 105.8ms
# image 82/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF6594_JPG.rf.07a518561f449c80c42d6816404be1b0.jpg: 1280x1280 1 10, 1 11, 1 17, 1 25, 2 acs, 3 als, 1 prn, 1 undefined, 105.7ms
# image 83/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF6681_JPG.rf.5e0659858c1e0e2b02e1421ea6826878.jpg: 1280x1280 1 13, 1 22, 2 acs, 1 al, 1 c, 1 ch, 1 cm, 1 ex, 1 ft, 2 gs, 2 lis, 1 ll, 2 mps, 1 n, 1 pg, 1 prn, 1 sn, 105.6ms
# image 84/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF6852_JPG.rf.3c7299c46b185964bf21aa5c4c990ca8.jpg: 1280x1280 2 16s, 2 20s, 1 22, 2 6s, 3 acs, 2 als, 1 c, 2 chs, 2 cms, 1 ex, 1 ft, 2 gs, 1 li, 1 ll, 1 ls, 1 mp, 1 sn, 2 undefineds, 106.4ms
# image 85/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF7276_JPG.rf.ad4dfa391bd9d916e78a11e822cffec8.jpg: 1280x1280 2 19s, 2 20s, 1 22, 4 acs, 3 als, 2 cs, 2 chs, 1 cm, 2 ens, 1 ex, 4 fts, 1 li, 3 lls, 1 ls, 2 mps, 1 prn, 1 sn, 2 sts, 3 undefineds, 105.6ms
# image 86/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF7693_JPG.rf.ae8418211488925aae45ff8e0d5204f2.jpg: 1280x1280 2 16s, 1 19, 3 20s, 1 22, 1 3, 2 acs, 3 als, 2 cs, 2 chs, 2 ens, 2 exs, 3 fts, 1 g, 2 gns, 1 li, 2 lls, 1 ls, 1 mp, 1 n, 2 prns, 1 sn, 105.5ms
# image 87/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF7763_JPG.rf.740e161093a90e8eadcba4c287af9691.jpg: 1280x1280 1 10, 1 20, 1 3, 2 acs, 2 als, 2 cs, 1 ch, 2 gs, 2 lis, 1 ll, 1 ls, 1 mp, 2 ns, 2 pgs, 2 pras, 1 prn, 1 sa, 1 sba, 1 sn, 1 st, 105.4ms
# image 88/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF7852_JPG.rf.2768d6fe7f7d3ef1071365432acbdad6.jpg: 1280x1280 2 1s, 1 al, 2 cs, 1 ch, 1 cm, 1 ex, 2 gs, 1 gn, 1 li, 1 ll, 1 ls, 1 mp, 2 ns, 2 pgs, 1 prn, 1 sn, 107.3ms
# image 89/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF8274_JPG.rf.dcad796c387446aeefb04a7e89e1e47e.jpg: 1280x1280 1 ac, 2 als, 2 cs, 1 ch, 2 cms, 2 exs, 1 ft, 1 g, 1 gn, 1 li, 1 ll, 1 ls, 1 mp, 1 pg, 1 prn, 1 sba, 1 sn, 1 st, 105.7ms
# image 90/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF8324_JPG.rf.aa03562a42df4dcf003193bf82b370ef.jpg: 1280x1280 2 16s, 4 19s, 2 20s, 2 22s, 1 3, 1 6, 2 acs, 2 als, 3 cs, 2 chs, 1 cm, 2 ens, 3 exs, 3 fts, 2 gs, 1 gn, 1 li, 2 lls, 1 ls, 1 mp, 1 n, 1 prn, 1 sn, 1 st, 2 undefineds, 105.4ms
# image 91/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF8355_JPG.rf.a11a4ddbf137c2221f5525985d236acc.jpg: 1280x1280 1 1, 1 ac, 1 al, 2 cs, 1 ch, 1 cm, 1 ex, 1 g, 2 gns, 2 lis, 1 ll, 1 ls, 1 mp, 1 n, 1 pg, 1 prn, 1 sn, 1 st, 105.5ms
# image 92/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF8811_JPG.rf.5e0a29f51e8c415266f606e0abbdd644.jpg: 1280x1280 2 16s, 2 19s, 2 20s, 2 22s, 1 6, 4 acs, 2 als, 2 cs, 2 chs, 1 cm, 2 ens, 1 ex, 1 ft, 2 gs, 1 gn, 1 li, 2 lls, 1 ls, 1 pg, 1 prn, 1 sn, 2 sts, 4 undefineds, 104.3ms
# image 93/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF8830_JPG.rf.31f91940da7b31f6410d731c28ec47eb.jpg: 1280x1280 1 1, 1 13, 1 ac, 2 als, 2 cs, 1 ch, 2 cms, 1 ex, 2 fts, 1 g, 3 lis, 2 lls, 1 mp, 1 pg, 1 pra, 1 prn, 2 sas, 1 sba, 1 sn, 2 sts, 105.7ms
# image 94/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF8838_JPG.rf.f916d9e9925555b44f2b96614c90424c.jpg: 1280x1280 2 16s, 3 19s, 4 20s, 4 22s, 2 3s, 1 6, 3 acs, 4 als, 2 cs, 2 chs, 2 ens, 3 fts, 1 g, 1 gn, 2 lis, 1 ll, 1 ls, 1 pg, 1 prn, 1 sn, 1 st, 2 undefineds, 105.5ms
# image 95/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF9080_JPG.rf.29684ab79bde05d84a1d1837afd9c592.jpg: 1280x1280 2 acs, 1 al, 2 cs, 1 ch, 2 cms, 1 g, 2 lis, 1 ll, 1 ls, 1 mp, 2 ns, 1 pg, 1 pra, 1 prn, 1 r, 1 sn, 105.8ms
# image 96/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF9088_JPG.rf.bd2d080154173c3071b2e31b17b6cf70.jpg: 1280x1280 1 10, 2 17s, 2 acs, 4 als, 1 c, 1 prn, 1 sn, 4 undefineds, 106.2ms
# image 97/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF9153_JPG.rf.32bb4ec255b7dd1dd6d43efa90b263c3.jpg: 1280x1280 1 13, 1 20, 1 3, 1 ac, 2 als, 2 cs, 2 chs, 1 cm, 1 ex, 3 gs, 1 gn, 3 lis, 1 ll, 1 mp, 1 n, 2 pgs, 1 prn, 1 sn, 105.8ms
# image 98/100 /content/yolov9/Facial-Landmark-9/test/images/DSCF9654_JPG.rf.6420f8f844a47eb6aa108f90b671e0bf.jpg: 1280x1280 1 11, 1 25, 2 acs, 1 c, 1 undefined, 105.8ms
# image 99/100 /content/yolov9/Facial-Landmark-9/test/images/IMG_0625_JPG.rf.337fc29a20b25051c7070be895f516ba.jpg: 1280x1280 1 1, 1 ac, 1 al, 1 c, 1 ch, 1 cm, 2 exs, 2 gs, 1 gn, 1 li, 2 lls, 1 ls, 1 mp, 2 ns, 2 pgs, 1 pra, 1 prn, 1 sn, 2 sts, 107.3ms
# image 100/100 /content/yolov9/Facial-Landmark-9/test/images/IMG_2735_jpeg.rf.044408a533ef2156746a79ecf2250e26.jpg: 1280x1280 2 acs, 1 c, 1 ch, 1 cm, 2 exs, 1 g, 2 lis, 2 lls, 1 ls, 1 mp, 1 n, 1 pg, 1 pra, 1 prn, 1 sba, 1 sn, 1 st, 1 undefined, 107.4ms
# Speed: 1.9ms pre-process, 105.8ms inference, 6.3ms NMS per image at shape (1, 3, 1280, 1280)
# Results saved to runs/detect/exp

# %% [markdown]
# **NOTE:** Just like behore, the inference results have been saved in the appropriate directory inside `{HOME}/yolov9/runs/detect/`. Let's examine few of those results.

# %%
import glob

from IPython.display import Image, display

for image_path in glob.glob(f'{HOME}/yolov9/runs/detect/exp/*.jpg')[:10]:
      display(Image(filename=image_path, width=600))

# %% [markdown]
# ## BONUS: Deploy YOLOv9 Model with Inference

# %% [markdown]
# **NOTE:** To deploy the model and display inference results, we will need two additional packages - [`inference`](https://pypi.org/project/inference) and [`supervision`](https://pypi.org/project/supervision). Let's install and import them!

# %%
# !pip install -q inference supervision
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.5/345.5 kB 7.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.1/97.1 kB 10.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.2/59.2 kB 8.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 20.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.9/91.9 kB 13.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.8/251.8 kB 31.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.7/239.7 kB 28.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 34.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.0/66.0 kB 8.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.1/267.1 kB 32.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.7/65.7 kB 9.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 940.0/940.0 kB 35.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 17.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 50.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.1/148.1 kB 20.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 kB 6.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 746.9/746.9 kB 60.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.9/384.9 kB 42.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.7/17.7 MB 68.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.8/143.8 kB 20.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 100.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 94.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 97.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 11.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 7.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 10.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 7.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 11.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 101.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 102.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 95.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 75.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 103.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 93.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 16.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 104.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 95.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 35.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 101.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 71.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 40.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 77.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 74.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 63.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 94.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 106.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 106.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 99.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 103.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 102.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 12.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 94.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 93.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 106.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 96.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 106.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 95.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 106.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 88.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 95.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 107.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 105.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 103.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 96.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 107.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 97.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 99.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 107.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 93.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 12.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 94.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 107.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 98.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 102.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 99.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 98.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 92.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 78.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 97.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 79.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 104.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 99.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 70.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 72.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 75.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 71.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 16.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 93.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 112.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 96.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 102.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 102.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 106.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 98.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 104.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 106.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 99.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 109.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 111.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 107.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 97.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 99.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 106.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 107.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 101.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 96.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 11.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 99.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 94.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 104.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 107.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 98.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 97.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 96.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 40.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 101.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 106.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 91.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 102.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 103.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 100.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 100.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 101.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 107.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 105.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 39.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 68.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 17.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 60.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 63.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 80.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 89.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 548.2/548.2 kB 53.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 102.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 100.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 104.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 107.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 100.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 48.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 25.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 99.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 101.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 101.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 102.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 91.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 104.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 101.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 107.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 101.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 99.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 16.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 96.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 95.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 107.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 101.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 105.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 95.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 108.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 107.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 103.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 106.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 78.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 106.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 109.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 16.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 106.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 105.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 102.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 99.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 106.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 102.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 71.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 76.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 73.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 77.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 68.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 73.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 67.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 16.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 71.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 104.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 105.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 91.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 102.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 106.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 105.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 111.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 98.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 95.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 98.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 100.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 89.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 21.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 89.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 100.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 12.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 12.5 MB/s eta 0:00:00
#   Building wheel for GPUtil (setup.py) ... done

# %%
import cv2
import random
import getpass

import supervision as sv

from inference import get_model

# %matplotlib inline
# Out:
# SupervisionWarnings: BoxAnnotator is deprecated: `BoxAnnotator` is deprecated and will be removed in `supervision-0.22.0`. Use `BoundingBoxAnnotator` and `LabelAnnotator` instead

# %% [markdown]
# **NOTE:** Before using your model in Inference, you first need to upload your weights to Roboflow Universe. Ensure to specify the correct `model_type` - `yolov9`, and that the project version matches the version of the dataset you used for training, denoted by `[1]`. In my case, it's `6`.
#
# ![YOLOv9 Benchmark](https://storage.googleapis.com/com-roboflow-marketing/notebooks/examples/upload-roboflow-model.png)

# %%
version.deploy(model_type="yolov9", model_path=f"{HOME}/yolov9/runs/train/exp")
# Out:
# An error occured when getting the model upload URL: 404 Client Error: Not Found for url: https://api.roboflow.com/ueh-tb3hq/facial-landmark-125ft/9/uploadModel?api_key=ZOPETSNpOENTPTAZXRyk&modelType=yolov9&nocache=true

# %% [markdown]
# **NOTE:** Now we can download our model anywhere using the assigned `model_id` denoted by `[2]`. In my case `football-players-detection-3zvbc/6`. To download the model you will need your [`ROBOFLOW_API_KEY`](https://docs.roboflow.com/api-reference/authentication).

# %%
ROBOFLOW_API_KEY = getpass.getpass()

model = get_model(model_id="football-players-detection-3zvbc/8", api_key=ROBOFLOW_API_KEY)
# Out:
# ··········

# %% [markdown]
# **NOTE:** Let's pick random image from our test subset and detect objects using newly fine-tuned model.

# %%
image_paths = sv.list_files_with_extensions(
    directory=f"{dataset.location}/test/images",
    extensions=['png', 'jpg', 'jpeg']
)
image_path = random.choice(image_paths)
image = cv2.imread(image_path)

result = model.infer(image, confidence=0.1)[0]
detections = sv.Detections.from_inference(result)

# %% [markdown]
# **NOTE:** Finally, let's use supervision and [annotate](https://supervision.roboflow.com/develop/annotators/) our results.

# %%
label_annotator = sv.LabelAnnotator(text_color=sv.Color.BLACK)
bounding_box_annotator = sv.BoundingBoxAnnotator()

annotated_image = image.copy()
annotated_image = bounding_box_annotator.annotate(scene=annotated_image, detections=detections)
annotated_image = label_annotator.annotate(scene=annotated_image, detections=detections)

sv.plot_image(annotated_image)
